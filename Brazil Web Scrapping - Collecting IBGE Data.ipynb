# %%
import pandas as pd
import pandas_gbq

from google.oauth2 import service_account

key_path = "./app/gkeys/epidemicapp-62d0d471b86f.json"
CREDENTIALS  = service_account.Credentials.from_service_account_file(key_path)
pandas_gbq.context.credentials = CREDENTIALS

# %%
query_data = """
    select *
    from br_general.cities_coordinates
"""

cities_df = pandas_gbq.read_gbq(query_data, project_id="epidemicapp-280600")
cities_df.head()
# Out:
# Downloading: 100%|██████████| 2540/2540 [00:00<00:00, 2980.56rows/s]
#                    city state country        lat       long
# 0         Rio Branco/AC    AC  Brasil  -9.976536 -67.822078
# 1  Plácido de Castro/AC    AC  Brasil -10.323915 -67.182420
# 2    Cruzeiro do Sul/AC    AC  Brasil  -7.630796 -72.670387
# 3         Acrelândia/AC    AC  Brasil -10.075917 -67.052690
# 4   Senador Guiomard/AC    AC  Brasil  -9.976500 -67.319140

# %%
import unidecode
import random
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains

options = webdriver.ChromeOptions()
# options.add_argument('headless')
# options.add_argument('window-size=1920x1080')

driver = webdriver.Chrome("./app/gdriver/chromedriver", options=options)

# %%
dummie_url = ["https://www.linkedin.com/feed/", 
              "https://github.com/",
              "https://stackoverflow.com/",
              "https://twitter.com/home?lang=pt",
              "https://pt-br.facebook.com/"]
driver.get(dummie_url[0])

# %%
verbose_progress = True
verbose_pipeline = True
verbose_content = False
verbose_exceptions = False

counter_flag_control = 20
cities_list = cities_df["city"].unique().tolist()
social_scrap_url = "https://cidades.ibge.gov.br/brasil/{}/{}/panorama/"

df_tables = dict()

print("Running the scrapper...")
for city_name in cities_list:
    # Reinitializing the process flags
    concluded_flag = False
    test_flag = False
    test_counter = 0
    
    # Getting the state and city name from id
    city, state = city_name.replace(" ", "-").lower().split("/")
    # Creating the unicode version of the city and state
    city, state = unidecode.unidecode(city), unidecode.unidecode(state)
    # Create the scrapping url to fetch the data
    city_scrap_url = social_scrap_url.format(state, city)
    # Print the total progress
    if verbose_progress:
        print("  At => {} from {} -> {} in url => {}".format(
            cities_list.index(city_name), len(cities_list), city_name, city_scrap_url))
    
    # While no data is fetched, try getting 
    # the site response and the data
    while not concluded_flag and not test_flag:
        # Get the site response...
        if verbose_pipeline:
            print("    . Getting the url content...")
        driver.get(dummie_url[random.randint(0, 4)])
        driver.get(city_scrap_url)
        # Append the new actions to driver
        if verbose_pipeline:
            print("    . Including the actions module...")
        actions = ActionChains(driver)
        
        # Find the list headers to collected the data...
        p_elements = driver.find_elements_by_class_name("lista__cabecalho")
        if verbose_pipeline:
            print("    . Getting the lista elements --> {} elements!".format(len(p_elements)))
        
        # For each head element collect all data
        for element in p_elements:
            if verbose_content:
                print("\t\t -> At element: {}".format(element.text))
            if element.text not in df_tables.keys():
                df_tables[element.text] = pd.DataFrame()
            # Click on the element
            if element != p_elements[0] and test_counter == 0:
                actions.move_to_element(element)
                try:
                    actions.click(element)
                    actions.perform()
                except Exception as e:
                    print("\t\t => {}".format(e))
            # Find the element content
            name_elements = driver.find_elements_by_class_name("lista__nome")
            value_elements = driver.find_elements_by_class_name("lista__valor")
            if verbose_pipeline and element == p_elements[0]:
                print("    . Getting close to {} names and {} values".format(
                    len(name_elements), len(value_elements)))
            # Print the elements content
            new_city_content = dict()
            for n, v in zip(name_elements, value_elements):
                if n.text != "" and v.text != "":
                    # Create the numerical component
                    split_value = v.text.split(" ")
                    numeric_val = split_value[0].replace(".", "").replace(",", ".")
                    try:
                        numeric_val = float(numeric_val)
                        # Create the field text
                        split_name = n.text.split(" ")
                        split_name.pop(-1)
                        name_val = "_".join(split_name)
                        name_val = unidecode.unidecode(name_val.lower())
                        if verbose_content:
                            print("\t\t Item: {} => {}".format(n.text, v.text))
                            print("\t\t   * {} => {}".format(name_val, numeric_val))
                        if "%" in v.text.split(" "):
                            numeric_val *= 1/100.0
                            name_val = name_val + "_perc"
                        new_city_content[name_val] = [numeric_val]
                    except Exception as e:
                        if verbose_exceptions:
                            print(e)
            
            new_df = pd.DataFrame(new_city_content)
            if len(new_df) > 0:
                concluded_flag = True
                
            new_df["city"] = city_name
            df_tables[element.text] = pd.concat((df_tables[element.text], new_df))
            
        test_counter += 1
        if verbose_progress:
            print("\t\t\t => test {}".format(test_counter))
        if test_counter >= counter_flag_control:
            test_flag = True
            print("\t\t  => Flag error... tryed {} times...".format(counter_flag_control))
# Out:
# Running the scrapper...
#   At => 0 from 2540 -> Rio Branco/AC in url => https://cidades.ibge.gov.br/brasil/ac/rio-branco/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 4
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 5
#   At => 1 from 2540 -> Plácido de Castro/AC in url => https://cidades.ibge.gov.br/brasil/ac/placido-de-castro/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 2 from 2540 -> Cruzeiro do Sul/AC in url => https://cidades.ibge.gov.br/brasil/ac/cruzeiro-do-sul/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 4
#   At => 3 from 2540 -> Acrelândia/AC in url => https://cidades.ibge.gov.br/brasil/ac/acrelandia/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 4 from 2540 -> Senador Guiomard/AC in url => https://cidades.ibge.gov.br/brasil/ac/senador-guiomard/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 5 from 2540 -> Tarauacá/AC in url => https://cidades.ibge.gov.br/brasil/ac/tarauaca/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 6 from 2540 -> Sena Madureira/AC in url => https://cidades.ibge.gov.br/brasil/ac/sena-madureira/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 4
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 5
#   At => 7 from 2540 -> Bujari/AC in url => https://cidades.ibge.gov.br/brasil/ac/bujari/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 4
#   At => 8 from 2540 -> Marechal Thaumaturgo/AC in url => https://cidades.ibge.gov.br/brasil/ac/marechal-thaumaturgo/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 2
#   At => 9 from 2540 -> Epitaciolândia/AC in url => https://cidades.ibge.gov.br/brasil/ac/epitaciolandia/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 2
#   At => 10 from 2540 -> Porto Acre/AC in url => https://cidades.ibge.gov.br/brasil/ac/porto-acre/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 4
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 5
#   At => 11 from 2540 -> Brasiléia/AC in url => https://cidades.ibge.gov.br/brasil/ac/brasileia/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 4
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 5
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 6
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 7
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 8
#   At => 12 from 2540 -> Xapuri/AC in url => https://cidades.ibge.gov.br/brasil/ac/xapuri/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 13 from 2540 -> Capixaba/AC in url => https://cidades.ibge.gov.br/brasil/ac/capixaba/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 2
#   At => 14 from 2540 -> Assis Brasil/AC in url => https://cidades.ibge.gov.br/brasil/ac/assis-brasil/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 4
#   At => 15 from 2540 -> Mâncio Lima/AC in url => https://cidades.ibge.gov.br/brasil/ac/mancio-lima/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 2
#   At => 16 from 2540 -> Rodrigues Alves/AC in url => https://cidades.ibge.gov.br/brasil/ac/rodrigues-alves/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 4
#   At => 17 from 2540 -> Feijó/AC in url => https://cidades.ibge.gov.br/brasil/ac/feijo/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At =>
panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 2
#   At => 47 from 2540 -> São José da Tapera/AL in url => https://cidades.ibge.gov.br/brasil/al/sao-jose-da-tapera/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 48 from 2540 -> Craíbas/AL in url => https://cidades.ibge.gov.br/brasil/al/craibas/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 4
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 5
#   At => 49 from 2540 -> Boca da Mata/AL in url => https://cidades.ibge.gov.br/brasil/al/boca-da-mata/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 4
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 5
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 6
#   At => 50 from 2540 -> Paripueira/AL in url => https://cidades.ibge.gov.br/brasil/al/paripueira/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 4
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 5
#   At => 51 from 2540 -> Coqueiro Seco/AL in url => https://cidades.ibge.gov.br/brasil/al/coqueiro-seco/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 52 from 2540 -> Penedo/AL in url => https://cidades.ibge.gov.br/brasil/al/penedo/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 2
#   At => 53 from 2540 -> Piaçabuçu/AL in url => https://cidades.ibge.gov.br/brasil/al/piacabucu/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 54 from 2540 -> Olho d'Água das Flores/AL in url => https://cidades.ibge.gov.br/brasil/al/olho-d'agua-das-flores/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 4 elements!
#     . Getting close to 38 names and 38 values
# 			 => test 4
#   At => 55 from 2540 -> Matriz de Camaragibe/AL in url => https://cidades.ibge.gov.br/brasil/al/matriz-de-camaragibe/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 2
#   At => 56 from 2540 -> Paulo Jacinto/AL in url => https://cidades.ibge.gov.br/brasil/al/paulo-jacinto/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 2
#   At => 57 from 2540 -> Quebrangulo/AL in url => https://cidades.ibge.gov.br/brasil/al/quebrangulo/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 58 from 2540 -> Passo de Camaragibe/AL in url => https://cidades.ibge.gov.br/brasil/al/passo-de-camaragibe/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 59 from 2540 -> Campo Alegre/AL in url => https://cidades.ibge.gov.br/brasil/al/campo-alegre/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 4
#   At => 60 from 2540 -> Japaratinga/AL in url => https://cidades.ibge.gov.br/brasil/al/japaratinga/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 61 from 2540 -> Joaquim Gomes/AL in url => https://cidades.ibge.gov.br/brasil/al/joaquim-gomes/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 2
#   At => 62 from 2540 -> Messias/AL in url => https://cidades.ibge.gov.br/brasil/al/messias/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 2
#   At => 63 from 2540 -> Viçosa/AL in url => https://cidades.ibge.gov.br/brasil/al/vicosa/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 4
#   At => 64 from 2540 -> Maribondo/AL in url => https://cidades.ibge.gov.br/brasil/al/maribondo/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 4
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 5
#   At => 65 from 2540 -> Colônia Leopoldina/AL in url => https://cidades.ibge.gov.br/brasil/al/colonia-leopoldina/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 2
#   At => 66 from 2540 -> Batalha/AL in url => https://cidades.ibge.gov.br/brasil/al/batalha/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 2
#   At => 67 from 2540 -> Major Isidoro/AL in url => https://cidades.ibge.gov.br/brasil/al/major-isidoro/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 68 from 2540 -> Porto de Pedras/AL in url => https://cidades.ibge.gov.br/brasil/al/porto-de-pedras/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 4
#   At => 69 from 2540 -> Barra de São Miguel/AL in url => https://cidades.ibge.gov.br/brasil/al/barra-de-sao-miguel/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 4
#   At => 70 from 2540 -> Delmiro Gouveia/AL in url => https://cidades.ibge.gov.br/brasil/al/delmiro-gouveia/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 71 from 2540 -> Girau do Ponciano/AL in url => https://cidades.ibge.gov.br/brasil/al/girau-do-ponciano/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 4
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 5
#   At => 72 from 2540 -> Barra de Santo Antônio/AL in url => https://cidades.ibge.gov.br/brasil/al/barra-de-santo-antonio/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 73 from 2540 -> Cajueiro/AL in url => https://cidades.ibge.gov.br/brasil/al/cajueiro/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 3
#   At => 74 from 2540 -> Pão de Açúcar/AL in url => https://cidades.ibge.gov.br/brasil/al/pao-de-acucar/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 2
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 3
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 4
#   At =>
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 6 elements!
#     . Getting close to 30 names and 30 values
# 			 => test 4
#   At => 326 from 2540 -> Maraú/BA in url => https://cidades.ibge.gov.br/brasil/ba/marau/panorama/
#     . Getting the url content...
#     . Including the actions module...
#     . Getting the lista elements --> 0 elements!
# 			 => test 1
#     . Getting the url content...

# %%
df_tables['POPULAÇÃO']
# Out:
#     populacao_estimada  populacao_no_ultimo_censo  densidade_demografica  \
# 0             407319.0                   336038.0                  38.03
# 0              19761.0                    17209.0                   8.86
# 0              88376.0                    78507.0                   8.94
# 0              15256.0                    12538.0                   6.94
# 0              23024.0                    20179.0                   8.69
# ..                 ...                        ...                    ...
# 0              17852.0                    18250.0                 206.33
# 0              12690.0                    12060.0                  51.67
# 0               6664.0                     6656.0                  51.48
# 0              28635.0                    26992.0                  85.48
# 0              20066.0                    19334.0                  80.38
#
#                         city  taxa_de_fecundidade  \
# 0              Rio Branco/AC                  NaN
# 0       Plácido de Castro/AC                  NaN
# 0         Cruzeiro do Sul/AC                  NaN
# 0              Acrelândia/AC                  NaN
# 0        Senador Guiomard/AC                  NaN
# ..                       ...                  ...
# 0          Lagoa da Canoa/AL                  NaN
# 0               Novo Lino/AL                  NaN
# 0                 Roteiro/AL                  NaN
# 0      Limoeiro de Anadia/AL                  NaN
# 0   Porto Real do Colégio/AL                  NaN
#
#     taxa_de_mortalidade_infantil  domicilios_com_iluminacao_eletrica_perc  \
# 0                            NaN                                      NaN
# 0                            NaN                                      NaN
# 0                            NaN                                      NaN
# 0                            NaN                                      NaN
# 0                            NaN                                      NaN
# ..                           ...                                      ...
# 0                            NaN                                      NaN
# 0                            NaN                                      NaN
# 0                            NaN                                      NaN
# 0                            NaN                                      NaN
# 0                            NaN                                      NaN
#
#     domicilios_com_lixo_coletado_diretamente_perc  \
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# ..                                            ...
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
#
#     domicilios_com_rede_geral_como_principal_forma_de_abastecimento_de_agua_perc  \
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# ..                                                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#     domicilios_com_esgotamento_sanitario_(rede_geral_ou_fossa_septica_ligada_a_rede)_perc  \
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# ..                                                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#     domicilios_com_microcomputador_ou_tablet_perc  \
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# ..                                            ...
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
#
#     domicilios_com_acesso_a_internet_perc  \
# 0                                     NaN
# 0                                     NaN
# 0                                     NaN
# 0                                     NaN
# 0                                     NaN
# ..                                    ...
# 0                                     NaN
# 0                                     NaN
# 0                                     NaN
# 0                                     NaN
# 0                                     NaN
#
#     domicilios_com_telefone_movel_celular_perc  domicilios_com_televisao_perc  \
# 0                                          NaN                            NaN
# 0                                          NaN                            NaN
# 0                                          NaN                            NaN
# 0                                          NaN                            NaN
# 0                                          NaN                            NaN
# ..                                         ...                            ...
# 0                                          NaN                            NaN
# 0                                          NaN                            NaN
# 0                                          NaN                            NaN
# 0                                          NaN                            NaN
# 0                                          NaN                            NaN
#
#     pessoas_de_15_anos_ou_mais_que_praticaram_atividade_fisica_perc
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# ..                                                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
# [86 rows x 15 columns]

# %%
df_tables.keys()
# Out:
# dict_keys(['POPULAÇÃO', 'TRABALHO E RENDIMENTO', 'EDUCAÇÃO', 'ECONOMIA', 'SAÚDE', 'TERRITÓRIO E AMBIENTE', 'INDÚSTRIA'])

# %%
p_elements = driver.find_elements_by_class_name("lista__titulo")

for element in p_elements:
    if element.text != "":
        print(element.text)

# %%
p_elements = driver.find_elements_by_class_name("lista__indicador")

for element in p_elements:
    if element.text != "":
        print(element.text)

# %%
city_scrap_url
